# %% [markdown]
# __<h2>Área 1: Projeto de Fábrica e Instalações Industriais</h2>__
# Dentro de Projeto de Fábrica e Instalações Industriais, pode-se utilizar a Geometria Analítica para diversas situações, porém a aplicação mais simples de demonstrar é a representação de instrumentos, setores e materiais como pontos em um plano cartesiano.

# %%
import matplotlib.pyplot as plt
import numpy as np
posx = [1,-2,4,-3]
posy = [3,2,-1,-4]
plt.title('Representação do chão de fábrica')
plt.grid()
plt.plot(posx, posy, 'ro')
plt.show()
